# %% [markdown]
# # Stats

# %%
# !pip3 install pymongo furl frozendict
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.7/site-packages (3.7.2)
# Requirement already satisfied: furl in /usr/local/lib/python3.7/site-packages (2.0.0)
# Collecting frozendict
#   Downloading https://files.pythonhosted.org/packages/4e/55/a12ded2c426a4d2bee73f88304c9c08ebbdbadb82569ebdd6a0c007cfd08/frozendict-1.2.tar.gz
# Requirement already satisfied: orderedmultidict>=1.0 in /usr/local/lib/python3.7/site-packages (from furl) (1.0)
# Requirement already satisfied: six>=1.8.0 in /usr/local/Cellar/ipython/6.4.0_1/libexec/vendor/lib/python3.7/site-packages (from furl) (1.11.0)
# Building wheels for collected packages: frozendict
#   Running setup.py bdist_wheel for frozendict ... done
#   Stored in directory: /Users/zerion/Library/Caches/pip/wheels/6c/6c/e9/534386165bd12cf1885582c75eb6d0ffcb321b65c23fe0f834
# Successfully built frozendict
# Installing collected packages: frozendict
# Successfully installed frozendict-1.2

# %%
import pymongo
from furl import furl
from collections import Counter

client = pymongo.MongoClient('mongodb://mongodb:itstimeformongodb@68.183.76.109:27017/')
db = client.crawlerSearchLinks
collection = db.searchItems

domain_counter = Counter()
for document in client.crawlerSearchLinks.searchItems.find({}):
    url = furl(document['URL'])
    domain_counter.update([url.origin])

len(domain_counter)
# Out:
# 2078

# %%
from frozendict import frozendict

grouped_by_inn = {}
for document in client.crawlerSearchLinks.searchItems.aggregate([
    {
        '$group': {
            '_id': "$INN",
            'urls': {'$push': '$URL'}
        }
    }
]):
    grouped_by_inn[document['_id']] = document['urls']

# %%
i = 0
for inn, urls in grouped_by_inn.items():
    if i > 10:
        break
    
    print(grouped_by_inn[inn])
#     grouped_by_inn[inn] = list(
#         filter(
#             lambda url: domain_counter[furl(url).origin] <= 10,
#             urls
#         )
#     )
#     print(grouped_by_inn[inn])
    i += 1

len(grouped_by_inn)
# Out:
# []
# []
# ['https://www.red-media.ru/news/2902/', 'http://voljsk.bezformata.com/listnews/litcenziatom-ooo-tpo-nadezhda/7697645/']
# ['https://www.red-media.ru/news/2902/', 'http://voljsk.bezformata.com/listnews/litcenziatom-ooo-tpo-nadezhda/7697645/']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# 3268

# %%
for item in org_items:
    print(item['URL'], item['TITLE'], item['INN'])
# Out:
# https://sk.ru/news/m/wiki/4561/download.aspx sk.ru 7701899276
# https://sk.ru/news/m/wiki/4234/download.aspx sk.ru 7709270056
# https://sk.ru/cfs-file.ashx/__key/telligent-evolution-components-attachments/13-372-00-00-00-00-44-68/2012_5F00_11_5F00_29-_230447043004410442043D0438043A043804_-_1F0440043E0435043A0442043004_-_2800_747_29005F00_Ru.xls XLS sk.ru 7701899300
# https://sk.ru/news/m/wiki/7015/download.aspx sk.ru 7702765035
# https://sk.ru/news/m/tenderdocs/19166/download.aspx Протокол - sk.ru 7702131247
# https://sk.ru/cfs-file.ashx/__key/telligent-evolution-components-attachments/13-372-00-00-00-00-45-61/2012_5F00_12_5F00_07-_230447043004410442043D0438043A043804_-_1F0440043E0435043A0442043004_-_2800_761_29005F00_Ru.xls XLS sk.ru 7701899276
# https://sk.ru/news/m/wiki/4224/download.aspx sk.ru 7701899276
# https://sk.ru/news/m/wiki/4212/download.aspx sk.ru 7702765035
# https://sk.ru/news/m/wiki/6759/download.aspx sk.ru 7707762430
# https://sk.ru/net/1110227/ ООО "НОВАС Ск" - Skolkovo Community 7707762430

# %%
import pandas

domain_counter_df = pandas.DataFrame.from_dict(domain_counter, orient='index')
for index, row in domain_counter_df.sort_values(by=[0], ascending=True)[:200].iterrows():
    print('gg', row)
# Out:
# gg 0    1
# Name: https://eit-eurasia.tiu.ru, dtype: int64
# gg 0    1
# Name: http://gala-estate.com, dtype: int64
# gg 0    1
# Name: http://xn----7sbajbjgkrb8bebvs2agl4q.xn--p1ai, dtype: int64
# gg 0    1
# Name: http://kaliningrad.rusbport.ru, dtype: int64
# gg 0    1
# Name: http://www.pmz.ru, dtype: int64
# gg 0    1
# Name: http://sterlitamak.ru, dtype: int64
# gg 0    1
# Name: https://echo.msk.ru, dtype: int64
# gg 0    1
# Name: http://perm.tizu.ru, dtype: int64
# gg 0    1
# Name: https://qujozy.wordpress.com, dtype: int64
# gg 0    1
# Name: http://aandp.ru, dtype: int64
# gg 0    1
# Name: http://razvilka48.ru, dtype: int64
# gg 0    1
# Name: http://bmgtrade.ru, dtype: int64
# gg 0    1
# Name: https://www.okeydostavka.ru, dtype: int64
# gg 0    1
# Name: http://kaliningrad.tizu.ru, dtype: int64
# gg 0    1
# Name: https://psibook.com, dtype: int64
# gg 0    1
# Name: http://xn--80aabfm6asckpenfhb5c.xn--p1ai, dtype: int64
# gg 0    1
# Name: http://www.concrete-union.ru, dtype: int64
# gg 0    1
# Name: http://www.tehnobeton.ru, dtype: int64
# gg 0    1
# Name: https://stroi.mos.ru, dtype: int64
# gg 0    1
# Name: http://pskovadmin.ru, dtype: int64
# gg 0    1
# Name: http://xn--d1afcruqc.xn--n1aaa.cc, dtype: int64
# gg 0    1
# Name: http://www.domspb.su, dtype: int64
# gg 0    1
# Name: http://fsproperty.ru, dtype: int64
# gg 0    1
# Name: https://exporv.ru, dtype: int64
# gg 0    1
# Name: http://www.rushydro.ru, dtype: int64
# gg 0    1
# Name: https://ar2017.rushydro.ru, dtype: int64
# gg 0    1
# Name: https://77.rkn.gov.ru, dtype: int64
# gg 0    1
# Name: https://k10-1.ru, dtype: int64
# gg 0    1
# Name: http://deltaestate.ru, dtype: int64
# gg 0    1
# Name: http://soyuz.spb.ru, dtype: int64
# gg 0    1
# Name: http://vera1.ru, dtype: int64
# gg 0    1
# Name: https://xn--l1a.xn----etbpba5admdlad.xn--p1ai, dtype: int64
# gg 0    1
# Name: http://www.orensun.com, dtype: int64
# gg 0    1
# Name: http://ooo-novayazhizn.ru, dtype: int64
# gg 0    1
# Name: http://an-nv.ru, dtype: int64
# gg 0    1
# Name: http://domnushka.ru, dtype: int64
# gg 0    1
# Name: http://www.miel.ru, dtype: int64
# gg 0    1
# Name: http://allestate.ru, dtype: int64
# gg 0    1
# Name: https://www.advecs.com, dtype: int64
# gg 0    1
# Name: https://vesco-realty.ru, dtype: int64
# gg 0    1
# Name: http://xn--90afbe4aobp.xn--p1ai, dtype: int64
# gg 0    1
# Name: https://stolica-group.ru, dtype: int64
# gg 0    1
# Name: http://www.oeaud.ru, dtype: int64
# gg 0    1
# Name: http://dava-ko.ru, dtype: int64
# gg 0    1
# Name: http://domodedovo.regreestr.com, dtype: int64
# gg 0    1
# Name: https://aslife.ru, dtype: int64
# gg 0    1
# Name: http://fedtomsk.directmarkets.ru, dtype: int64
# gg 0    1
# Name: http://11.rkn.gov.ru, dtype: int64
# gg 0    1
# Name: https://troparevo-nikulino.mos.ru, dtype: int64
# gg 0    1
# Name: https://plaza.rakuten.co.jp, dtype: int64
# gg 0    1
# Name: http://volgograd.tizu.ru, dtype: int64
# gg 0    1
# Name: http://www.bcg.su, dtype: int64
# gg 0    1
# Name: http://www.mip.pw, dtype: int64
# gg 0    1
# Name: http://elenahahaleva.com, dtype: int64
# gg 0    1
# Name: http://new-staff.ru, dtype: int64
# gg 0    1
# Name: https://www.keyword-suggest-tool.com, dtype: int64
# gg 0    1
# Name: https://xn--80apmglwl.xn--p1ai, dtype: int64
# gg 0    1
# Name: http://media.allcontainerlines.com, dtype: int64
# gg 0    1
# Name: http://www.gladsport.ru, dtype: int64
# gg 0    1
# Name: https://old.panteon.ru, dtype: int64
# gg 0    1
# Name: http://lipstat.gks.ru, dtype: int64
# gg 0    1
# Name: http://panteon.ru.composesite.com, dtype: int64
# gg 0    1
# Name: https://mkusouz.com, dtype: int64
# gg 0    1
# Name: https://ru.wikipedia.org, dtype: int64
# gg 0    1
# Name: http://moscow.enspe.com, dtype: int64
# gg 0    1
# Name: https://www.aslife.ru, dtype: int64
# gg 0    1
# Name: http://kostromskaya.okato.net, dtype: int64
# gg 0    1
# Name: http://www.mpgmig.ru, dtype: int64
# gg 0    1
# Name: https://git67.rostrud.ru, dtype: int64
# gg 0    1
# Name: http://cardtel.ru, dtype: int64
# gg 0    1
# Name: http://www.moktu.ru, dtype: int64
# gg 0    1
# Name: https://mjzk.ru, dtype: int64
# gg 0    1
# Name: https://yurtender.ru, dtype: int64
# gg 0    1
# Name: http://gstn.admin-smolensk.ru, dtype: int64
# gg 0    1
# Name: http://domodedovo.dumav.ru, dtype: int64
# gg 0    1
# Name: http://www.boomle.ru, dtype: int64
# gg 0    1
# Name: https://ved-import.com, dtype: int64
# gg 0    1
# Name: http://89.rpn.gov.ru, dtype: int64
# gg 0    1
# Name: http://www.oboronstroy-sro.ru, dtype: int64
# gg 0    1
# Name: http://oblgazservis.ru, dtype: int64
# gg 0    1
# Name: http://moneyzzz.ru, dtype: int64
# gg 0    1
# Name: http://sro-perm.ru, dtype: int64
# gg 0    1
# Name: http://semenov.okato.net, dtype: int64
# gg 0    1
# Name: https://fis-service.ru, dtype: int64
# gg 0    1
# Name: http://npom-svarog.ru, dtype: int64
# gg 0    1
# Name: http://metakom-service.ru, dtype: int64
# gg 0    1
# Name: https://masterse.net, dtype: int64
# gg 0    1
# Name: http://putnik-baikal.ru, dtype: int64
# gg 0    1
# Name: https://www.citibank.ru, dtype: int64
# gg 0    1
# Name: https://augustborg.ru, dtype: int64
# gg 0    1
# Name: https://wiseeconomist.ru, dtype: int64
# gg 0    1
# Name: http://www.enstal.ru, dtype: int64
# gg 0    1
# Name: http://old.kremlin-moscow.com, dtype: int64
# gg 0    1
# Name: http://wisdomdedal.weebly.com, dtype: int64
# gg 0    1
# Name: https://www.yeiskraion.ru, dtype: int64
# gg 0    1
# Name: http://rabotamedia.ru, dtype: int64
# gg 0    1
# Name: http://gzakupki.com, dtype: int64
# gg 0    1
# Name: http://7mega.ru, dtype: int64
# gg 0    1
# Name: http://www.comnarcon.com, dtype: int64
# gg 0    1
# Name: http://www.analyz24.ru, dtype: int64
# gg 0    1
# Name: https://zp.vgorode.ua, dtype: int64
# gg 0    1
# Name: http://www.e-kuzbass.ru, dtype: int64
# gg 0    1
# Name: http://eqbiz.ru, dtype: int64
# gg 0    1
# Name: http://pharmag.ru, dtype: int64
# gg 0    1
# Name: http://xn--e1aljj.xn--p1ai, dtype: int64
# gg 0    1
# Name: http://data.cbonds.info, dtype: int64
# gg 0    1
# Name: http://www.projectviolet.eu, dtype: int64
# gg 0    1
# Name: http://kolomnastepan.weebly.com, dtype: int64
# gg 0    1
# Name: https://srosp.ru, dtype: int64
# gg 0    1
# Name: http://media.rspp.ru, dtype: int64
# gg 0    1
# Name: http://domodedovo.okato.net, dtype: int64
# gg 0    1
# Name: http://rudocs.exdat.com, dtype: int64
# gg 0    1
# Name: http://kotelniki.okato.net, dtype: int64
# gg 0    1
# Name: http://xn--b1afcicp0bge.net, dtype: int64
# gg 0    1
# Name: https://rosavtotransport.ru, dtype: int64
# gg 0    1
# Name: https://vnt24.ru, dtype: int64
# gg 0    1
# Name: http://samcomsys.ru, dtype: int64
# gg 0    1
# Name: https://realnoevremya.ru, dtype: int64
# gg 0    1
# Name: http://astana.rusmet.ru, dtype: int64
# gg 0    1
# Name: https://www.ipbr.org, dtype: int64
# gg 0    1
# Name: http://www.tvertas.ru, dtype: int64
# gg 0    1
# Name: http://infomine.ru, dtype: int64
# gg 0    1
# Name: http://zakupki.cap.ru, dtype: int64
# gg 0    1
# Name: http://www.osbi.ru, dtype: int64
# gg 0    1
# Name: https://www.yuga.ru, dtype: int64
# gg 0    1
# Name: https://wejysa.wordpress.com, dtype: int64
# gg 0    1
# Name: http://titulusforum.org, dtype: int64
# gg 0    1
# Name: https://ipps.hse.ru, dtype: int64
# gg 0    1
# Name: https://busedu.hse.ru, dtype: int64
# gg 0    1
# Name: http://www.ugancfo.ru, dtype: int64
# gg 0    1
# Name: http://www.energo-obeng.ru, dtype: int64
# gg 0    1
# Name: https://www.srosp.ru, dtype: int64
# gg 0    1
# Name: http://perm-yel.ru, dtype: int64
# gg 0    1
# Name: https://www.archi.ru, dtype: int64
# gg 0    1
# Name: https://trud.krskstate.ru, dtype: int64
# gg 0    1
# Name: https://roi4cio.com, dtype: int64
# gg 0    1
# Name: http://reutov6a.ru, dtype: int64
# gg 0    1
# Name: https://wiki.svsreut.ru, dtype: int64
# gg 0    1
# Name: https://adnote.livejournal.com, dtype: int64
# gg 0    1
# Name: http://vtbreg.com, dtype: int64
# gg 0    1
# Name: https://www.belpressa.ru, dtype: int64
# gg 0    1
# Name: https://sodstr.ru, dtype: int64
# gg 0    1
# Name: https://moonback.ru, dtype: int64
# gg 0    1
# Name: https://norgispress.ru, dtype: int64
# gg 0    1
# Name: http://m-sertif.ru, dtype: int64
# gg 0    1
# Name: https://sikejuparezo.wordpress.com, dtype: int64
# gg 0    1
# Name: http://www.raapa.ru, dtype: int64
# gg 0    1
# Name: https://hiwowefisuz.wordpress.com, dtype: int64
# gg 0    1
# Name: http://a5classic.tilda.ws, dtype: int64
# gg 0    1
# Name: http://www.prizolovy.ru, dtype: int64
# gg 0    1
# Name: http://promleader.real-sector.ru, dtype: int64
# gg 0    1
# Name: https://flops.ru, dtype: int64
# gg 0    1
# Name: https://jidohypo.wordpress.com, dtype: int64
# gg 0    1
# Name: http://dobrovputi.org, dtype: int64
# gg 0    1
# Name: http://quickmurderfp.weebly.com, dtype: int64
# gg 0    1
# Name: https://rutend.ru, dtype: int64
# gg 0    1
# Name: http://kalugaobl.ajeo.ru, dtype: int64
# gg 0    1
# Name: http://guns.allzip.org, dtype: int64
# gg 0    1
# Name: http://onlinehelp24.ru, dtype: int64
# gg 0    1
# Name: http://fedizhevsk.directmarkets.ru, dtype: int64
# gg 0    1
# Name: http://legalacts.ru, dtype: int64
# gg 0    1
# Name: http://kazan.tendermedia.ru, dtype: int64
# gg 0    1
# Name: http://chtz.ru, dtype: int64
# gg 0    1
# Name: http://srobsk.ru, dtype: int64
# gg 0    1
# Name: http://economy.gov.ru, dtype: int64
# gg 0    1
# Name: http://zakaz.tomsk.gov.ru, dtype: int64
# gg 0    1
# Name: https://www.finam.ru, dtype: int64
# gg 0    1
# Name: http://fedperm.directmarkets.ru, dtype: int64
# gg 0    1
# Name: http://www.bankovskie.ru, dtype: int64
# gg 0    1
# Name: http://dw.melius7.com, dtype: int64
# gg 0    1
# Name: http://probnick.ru, dtype: int64
# gg 0    1
# Name: https://sysadmins.ru, dtype: int64
# gg 0    1
# Name: http://technocongress.ru, dtype: int64
# gg 0    1
# Name: https://rostec.ru, dtype: int64
# gg 0    1
# Name: http://www.trportal.ru, dtype: int64
# gg 0    1
# Name: http://volgastat.gks.ru, dtype: int64
# gg 0    1
# Name: https://nsovetnik.ru, dtype: int64
# gg 0    1
# Name: https://mmgp.ru, dtype: int64
# gg 0    1
# Name: https://promopomidorka.ru, dtype: int64
# gg 0    1
# Name: https://otzovikator.ru, dtype: int64
# gg 0    1
# Name: http://thrrrss.blog.fc2.com, dtype: int64
# gg 0    1
# Name: http://stavstat.gks.ru, dtype: int64
# gg 0    1
# Name: http://xn--80awqcc.xn--p1ai, dtype: int64
# gg 0    1
# Name: http://pulse3.jbl-msk24.ru, dtype: int64
# gg 0    1
# Name: http://primstat.gks.ru, dtype: int64
# gg 0    1
# Name: http://keramosart.weebly.com, dtype: int64
# gg 0    1
# Name: https://euroalliance.ru, dtype: int64
# gg 0    1
# Name: http://fedvladimir.directmarkets.ru, dtype: int64
# gg 0    1
# Name: http://shop.ekaterina-foundation.ru, dtype: int64
# gg 0    1
# Name: http://www.prizolov.pp.ru, dtype: int64
# gg 0    1
# Name: http://www.webrunscontent.ru, dtype: int64
# gg 0    1
# Name: http://omnpk-energetika.ru, dtype: int64
# gg 0    1
# Name: http://remtlt.ru, dtype: int64
# gg 0    1
# Name: https://tinyzezece.wordpress.com, dtype: int64
# gg 0    1
# Name: https://www.intourist.ru, dtype: int64
# gg 0    1
# Name: http://vladimirobl.ajeo.ru, dtype: int64
# gg 0    1
# Name: http://forum.turizm.ru, dtype: int64
# gg 0    1
# Name: http://zolotoevremya.ru, dtype: int64
# gg 0    1
# Name: http://www.mnpp-sven.ru, dtype: int64
# gg 0    1
# Name: https://www.rea.ru, dtype: int64
